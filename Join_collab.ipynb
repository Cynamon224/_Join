# %% [markdown]
# <a href="https://colab.research.google.com/github/Cynamon224/_Join/blob/dev/Join.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !wget https://raw.githubusercontent.com/Cynamon224/_Join/dev/factbook.csv
# Out:
# --2022-04-01 00:33:29--  https://raw.githubusercontent.com/Cynamon224/_Join/dev/factbook.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64856 (63K) [text/plain]
# Saving to: ‘factbook.csv.7’
#
# factbook.csv.7      100%[===================>]  63.34K  --.-KB/s    in 0.01s
#
# 2022-04-01 00:33:29 (5.31 MB/s) - ‘factbook.csv.7’ saved [64856/64856]

# %% [markdown]
# I downloaded dataset from https://perso.telecom-paristech.fr/eagan/class/igr204/datasets

# %%
df=pd.read_csv('factbook.csv',sep=";")
df = df.drop(labels=0, axis=0)
df.head(10)
# Out:
#                 Country Area(sq km) Birth rate(births/1000 population)  \
# 1           Afghanistan      647500                              47.02
# 2              Akrotiri         123                                NaN
# 3               Albania       28748                              15.08
# 4               Algeria     2381740                              17.13
# 5        American Samoa         199                              23.13
# 6               Andorra         468                               9.00
# 7                Angola     1246700                              44.64
# 8              Anguilla         102                              14.26
# 9            Antarctica    14000000                                NaN
# 10  Antigua and Barbuda         443                              17.26
#
#    Current account balance Death rate(deaths/1000 population) Debt - external  \
# 1                      NaN                              20.75      8000000000
# 2                      NaN                                NaN             NaN
# 3               -504000000                               5.12      1410000000
# 4              11900000000                               4.60     21900000000
# 5                      NaN                               3.33             NaN
# 6                      NaN                               6.07             NaN
# 7                -37880000                              25.90     10450000000
# 8                      NaN                               5.43         8800000
# 9                      NaN                                NaN             NaN
# 10                     NaN                               5.44       231000000
#
#    Electricity - consumption(kWh) Electricity - production(kWh)      Exports  \
# 1                       652200000                     540000000    446000000
# 2                             NaN                           NaN          NaN
# 3                      6760000000                    5680000000    552400000
# 4                     23610000000                   25760000000  32160000000
# 5                       120900000                     130000000     30000000
# 6                             NaN                           NaN     58000000
# 7                      1587000000                    1707000000  12760000000
# 8                        42600000                           NaN      2600000
# 9                             NaN                           NaN          NaN
# 10                      103000000                     110800000    689000000
#
#              GDP  ... Oil - production(bbl/day) Oil - proved reserves(bbl)  \
# 1    21500000000  ...                         0                          0
# 2            NaN  ...                       NaN                        NaN
# 3    17460000000  ...                      2000                  185500000
# 4   212300000000  ...                   1200000                11870000000
# 5      500000000  ...                         0                        NaN
# 6     1900000000  ...                       NaN                        NaN
# 7    23170000000  ...                    980000                22880000000
# 8      112000000  ...                       NaN                        NaN
# 9            NaN  ...                       NaN                        NaN
# 10     750000000  ...                         0                        NaN
#
#    Population Public debt(% of GDP) Railways(km)  \
# 1    29928987                   NaN          NaN
# 2         NaN                   NaN          NaN
# 3     3563112                   NaN          447
# 4    32531853                 37.40         3973
# 5       57881                   NaN          NaN
# 6       70549                   NaN          NaN
# 7    11190786                   NaN         2761
# 8       13254                   NaN          NaN
# 9         NaN                   NaN          NaN
# 10      68722                   NaN          NaN
#
#    Reserves of foreign exchange & gold Telephones - main lines in use  \
# 1                                  NaN                          33100
# 2                                  NaN                            NaN
# 3                           1206000000                         255000
# 4                          43550000000                        2199600
# 5                                  NaN                          15000
# 6                                  NaN                          35000
# 7                            800000000                          96300
# 8                                  NaN                           6200
# 9                                  NaN                              0
# 10                                 NaN                          38000
#
#    Telephones - mobile cellular Total fertility rate(children born/woman)  \
# 1                         15000                                      6.75
# 2                           NaN                                       NaN
# 3                       1100000                                      2.04
# 4                       1447310                                      1.92
# 5                          2377                                      3.25
# 6                         23500                                      1.29
# 7                        130000                                      6.27
# 8                          1800                                      1.73
# 9                           NaN                                       NaN
# 10                        38200                                      2.26
#
#    Unemployment rate(%)
# 1                   NaN
# 2                   NaN
# 3                 14.80
# 4                 25.40
# 5                  6.00
# 6                  0.00
# 7                   NaN
# 8                  8.00
# 9                   NaN
# 10                11.00
#
# [10 rows x 45 columns]

# %% [markdown]
# It isn't perfect data to work on for joining files but it was the best I found.

# %% [markdown]
# I split the data on two data frame to merge them together later.

# %%
DF1=df.filter(['Country', 'Area(sq km)', 'Birth rate(births/1000 population)',
       'Current account balance', 'Death rate(deaths/1000 population)',
       'Debt - external', ])
DF2=df.filter(['Country','Military expenditures - dollar figure',
       'Military expenditures - percent of GDP(%)',
       'Natural gas - consumption(cu m)'])

# %% [markdown]
# I saved this two df to .csv files, because we need path for program to work

# %%
DF1.to_csv('DF1.csv', encoding = 'utf-8-sig',index=False) 
DF2.to_csv('DF2.csv', encoding = 'utf-8-sig',index=False)

# %%
def join(path1,path2,columnName,join):

  try:
    df1=pd.read_csv(path1)
  except:
    print("Wrong path1")
  try:
    df2=pd.read_csv(path2)
  except:
    print("Wrong path2")

  col1=list(df1.columns)
  col2=list(df2.columns)

  if columnName not in col1:
    print("This column name doesn't exist in file1")
    return
  if columnName not in col2:
    print("This column name doesn't exist in file2")
    return

  dfNew=pd.DataFrame
  join=join.strip().lower()

  if(join=="left"):
    dfNew=pd.merge(df1,df2,how="left",left_on=columnName,right_on=columnName)
  elif(join=="right"):
    dfNew=pd.merge(df1,df2,how="right",left_on=columnName,right_on=columnName)
  elif(join=="inner"):
    dfNew=pd.merge(df1,df2,how="inner",left_on=columnName,right_on=columnName)
  else:
    dfNew=pd.merge(df1,df2,how="outer",left_on=columnName,right_on=columnName)
  return dfNew

# %% [markdown]
# I understood the assignment that I should add print(dfNew.head()) in function but I don't like the way it shows records so I did it outside the function.

# %%
df_inner=join("DF1.csv","DF2.csv","Country","inner")
df_inner.head()
# Out:
#           Country  Area(sq km)  Birth rate(births/1000 population)  \
# 0     Afghanistan       647500                               47.02
# 1        Akrotiri          123                                 NaN
# 2         Albania        28748                               15.08
# 3         Algeria      2381740                               17.13
# 4  American Samoa          199                               23.13
#
#    Current account balance  Death rate(deaths/1000 population)  \
# 0                      NaN                               20.75
# 1                      NaN                                 NaN
# 2            -5.040000e+08                                5.12
# 3             1.190000e+10                                4.60
# 4                      NaN                                3.33
#
#    Debt - external  Military expenditures - dollar figure  \
# 0     8.000000e+09                           1.884000e+08
# 1              NaN                                    NaN
# 2     1.410000e+09                           5.650000e+07
# 3     2.190000e+10                           2.480000e+09
# 4              NaN                                    NaN
#
#    Military expenditures - percent of GDP(%)  Natural gas - consumption(cu m)
# 0                                       2.60                     2.200000e+08
# 1                                        NaN                              NaN
# 2                                       1.49                     3.000000e+07
# 3                                       3.20                     2.232000e+10
# 4                                        NaN                              NaN

# %% [markdown]
# The join type parameter isn't case-sensitive and it ignores white space.

# %%
df_right=join("DF1.csv","DF2.csv","Country","Right")
df_right.head()
# Out:
#           Country  Area(sq km)  Birth rate(births/1000 population)  \
# 0     Afghanistan       647500                               47.02
# 1        Akrotiri          123                                 NaN
# 2         Albania        28748                               15.08
# 3         Algeria      2381740                               17.13
# 4  American Samoa          199                               23.13
#
#    Current account balance  Death rate(deaths/1000 population)  \
# 0                      NaN                               20.75
# 1                      NaN                                 NaN
# 2            -5.040000e+08                                5.12
# 3             1.190000e+10                                4.60
# 4                      NaN                                3.33
#
#    Debt - external  Military expenditures - dollar figure  \
# 0     8.000000e+09                           1.884000e+08
# 1              NaN                                    NaN
# 2     1.410000e+09                           5.650000e+07
# 3     2.190000e+10                           2.480000e+09
# 4              NaN                                    NaN
#
#    Military expenditures - percent of GDP(%)  Natural gas - consumption(cu m)
# 0                                       2.60                     2.200000e+08
# 1                                        NaN                              NaN
# 2                                       1.49                     3.000000e+07
# 3                                       3.20                     2.232000e+10
# 4                                        NaN                              NaN

# %%
df_left=join("DF1.csv","DF2.csv","Country"," LeFt ")
df_left.head()
# Out:
#           Country  Area(sq km)  Birth rate(births/1000 population)  \
# 0     Afghanistan       647500                               47.02
# 1        Akrotiri          123                                 NaN
# 2         Albania        28748                               15.08
# 3         Algeria      2381740                               17.13
# 4  American Samoa          199                               23.13
#
#    Current account balance  Death rate(deaths/1000 population)  \
# 0                      NaN                               20.75
# 1                      NaN                                 NaN
# 2            -5.040000e+08                                5.12
# 3             1.190000e+10                                4.60
# 4                      NaN                                3.33
#
#    Debt - external  Military expenditures - dollar figure  \
# 0     8.000000e+09                           1.884000e+08
# 1              NaN                                    NaN
# 2     1.410000e+09                           5.650000e+07
# 3     2.190000e+10                           2.480000e+09
# 4              NaN                                    NaN
#
#    Military expenditures - percent of GDP(%)  Natural gas - consumption(cu m)
# 0                                       2.60                     2.200000e+08
# 1                                        NaN                              NaN
# 2                                       1.49                     3.000000e+07
# 3                                       3.20                     2.232000e+10
# 4                                        NaN                              NaN

# %% [markdown]
# Outer type join is default type.

# %%
df_outer=join("DF1.csv","DF2.csv","Country"," doesn't matter it will be outer ")
df_outer.head()
# Out:
#           Country  Area(sq km)  Birth rate(births/1000 population)  \
# 0     Afghanistan       647500                               47.02
# 1        Akrotiri          123                                 NaN
# 2         Albania        28748                               15.08
# 3         Algeria      2381740                               17.13
# 4  American Samoa          199                               23.13
#
#    Current account balance  Death rate(deaths/1000 population)  \
# 0                      NaN                               20.75
# 1                      NaN                                 NaN
# 2            -5.040000e+08                                5.12
# 3             1.190000e+10                                4.60
# 4                      NaN                                3.33
#
#    Debt - external  Military expenditures - dollar figure  \
# 0     8.000000e+09                           1.884000e+08
# 1              NaN                                    NaN
# 2     1.410000e+09                           5.650000e+07
# 3     2.190000e+10                           2.480000e+09
# 4              NaN                                    NaN
#
#    Military expenditures - percent of GDP(%)  Natural gas - consumption(cu m)
# 0                                       2.60                     2.200000e+08
# 1                                        NaN                              NaN
# 2                                       1.49                     3.000000e+07
# 3                                       3.20                     2.232000e+10
# 4                                        NaN                              NaN

# %% [markdown]
# The data isn't perfect because there is no visible change to the dataframe whatever type of join we do. But I don't think it is a big problem because we use pandas function so there shouldn't be any errors (only when is something wrong with data).
